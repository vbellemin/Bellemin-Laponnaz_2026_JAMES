# %%
path_config = '../config_files/config_QGSW.py'

# %%
import sys
sys.path.append('../')

# %%
from src import exp
config = exp.Exp(path_config)
# Out:
# name_experiment: config_QGSW
# saveoutputs: True
# name_exp_save: config_QGSW
# path_save: /bettik/bellemva/MASSH_outputs/final_experiment_hawaii_itg/config_QGSW
# tmp_DA_path: /silenus/PROJECTS/pr-data-ocean/bellemva/scratch/final_experiment_hawaii_itg/config_QGSW
# flag_plot: 0
# init_date: 2012-05-01 00:00:00
# final_date: 2012-07-31 23:00:00
# assimilation_time_step: 1:00:00
# saveoutput_time_step: 1:00:00
# plot_time_step: 1 day, 0:00:00
# time_obs_min: None
# time_obs_max: None
# write_obs: True
# compute_obs: False
# path_obs: /silenus/PROJECTS/pr-data-ocean/bellemva/obs/final_experiment_hawaii_itg/config_QGSW
# coriolis_force: True
# n_workers: 10
# name_lon: lon
# name_lat: lat
# name_time: time
#
# NAME_DIAG is not set in the configuration file

# %%
from src import state as state
State = state.State(config)
# Out:
# super: GRID_GEO
# lon_min: 190.0
# lon_max: 200
# lat_min: 20.0
# lat_max: 30.0
# dlon: 0.0625
# dlat: 0.0625
# name_init_mask: None
# name_var_mask: {'lon': 'longitude', 'lat': 'latitude', 'var': 'ssh_it1'}
# interp_method_mask: nearest
# expand_pixel_mask: None

# %%
from src import inv as inv
res = inv.Inv(config,State)
# Out:
# super: INV_4DVAR
# compute_test: False
# path_init_4Dvar: None
# restart_4Dvar: False
# gtol: None
# ftol: 0.001
# n_consecutive: 100
# maxiter: 1000
# opt_method: L-BFGS-B
# save_minimization: True
# path_save_control_vectors: None
# timestep_checkpoint: 6:00:00
# sigma_R: 0.1
# sigma_B: None
# prec: True
# prescribe_background: False
# bkg_satellite: None
# path_background: None
# bkg_Kdiffus: 0.0
# name_bkg_var: res
# bkg_maxiter: 30
# bkg_maxiter_inner: 10
# largescale_error_ratio: 1
# only_largescale: False
# anomaly_from_bc: False
# save_rmse: False
# path_reference: None
# name_var_reference: {'lon': '', 'lat': ''}
# var_to_compare: {}
#
# super: MOD_QG1L_JAX
# name_class: Qgm
# name_var: {'SSH': 'ssh_bm'}
# name_init_var: {}
# dir_model: None
# var_to_save: None
# upwind: 3
# advect_pv: True
# advect_tracer: False
# dtmodel: 300
# time_scheme: Euler
# c0: 2.7
# filec_aux: None
# name_var_c: {'lon': '', 'lat': '', 'var': ''}
# cmin: None
# cmax: None
# solver: spectral
# init_from_bc: True
# dist_sponge_bc: None
# Kdiffus: None
# Kdiffus_trac: None
# bc_trac: OBC
# forcing_tracer_from_bc: False
# constant_c: True
# constant_f: True
# f0: None
# tile_size: 32
# tile_overlap: 16
# path_mdt: None
# name_var_mdt: None
#
#
# super: MOD_SW1L_JAX
# name_var: {'U': 'u_it', 'V': 'v_it', 'SSH': 'ssh_it'}
# name_init_var: None
# name_params: {'HE': 'He', 'HE_OFFSET': 'He_offset', 'HBCX': 'hbcx', 'HBCY': 'hbcy', 'ITG': 'itg'}
# dir_model: None
# var_to_save: ['SSH']
# dtmodel: 300
# time_scheme: rk4
# bc_kind: 1d
# bc_island: dirichlet
# w_waves: [0.00014051890262680206, 0.0001454441043328608, 0.000137879707490692]
# w_names: ['m2', 's2', 'n2']
# path_tidal_velocity: ../aux/FES_tide/
# path_bathymetry: ../aux/Bathymetry_hawaii.nc
# name_var_bathy: {'lon': 'lon', 'lat': 'lat', 'var': 'elevation'}
# smooth_wavelength: 36000
# He_init: 0.95
# He_data: None
# Ntheta: 2
# g: 9.81
#
#
# super: BC_EXT
# file: /bettik/bellemva/miost/miost_hawaii/miost_like_ssh_coarse/*.nc
# name_lon: longitude
# name_lat: latitude
# name_time: time
# name_var: {'SSH': 'ssh'}
#
# Observation information will be saved in dict_obs_SWOT_ALG_C2_J3_S3A_S3B_SWOT_NADIR_20120501_20120731_190_200_20_30_3600.txt
# Reading dict_obs_SWOT_ALG_C2_J3_S3A_S3B_SWOT_NADIR_20120501_20120731_190_200_20_30_3600.txt from previous run
# myOBSOP_Nadirs: super: OBSOP_INTERP_L3_JAX
# name_obs: ['ALG', 'C2', 'J3', 'S3A', 'S3B', 'SWOT_NADIR']
# name_var: SSH
# write_op: True
# path_save: /silenus/PROJECTS/pr-data-ocean/bellemva/obsop/long_serie/config_QGSW/obsop_nadirs
# compute_op: False
# Npix: 4
# mask_borders: False
# file_corr: None
# name_var_corr: None
# name_coord_corr: {'lon': 'longitude', 'lat': 'latitude', 'time': 'time'}
#
# myOBSOP_SWOT: super: OBSOP_INTERP_L4
# name_obs: ['SWOT']
# name_var: SSH
# write_op: True
# path_save: /silenus/PROJECTS/pr-data-ocean/bellemva/obsop/long_serie/config_QGSW/obsop_swot
# compute_op: False
# mask_borders: False
# interp_method: nearest
# gradients: False
# file_corr: None
# name_var_corr: None
# name_coord_corr: {'lon': 'longitude', 'lat': 'latitude', 'time': 'time'}
#
#
# super: OBSOP_INTERP_L3_JAX
# name_obs: ['ALG', 'C2', 'J3', 'S3A', 'S3B', 'SWOT_NADIR']
# name_var: SSH
# write_op: True
# path_save: /silenus/PROJECTS/pr-data-ocean/bellemva/obsop/long_serie/config_QGSW/obsop_nadirs
# compute_op: False
# Npix: 4
# mask_borders: False
# file_corr: None
# name_var_corr: None
# name_coord_corr: {'lon': 'longitude', 'lat': 'latitude', 'time': 'time'}
#
# super: OBSOP_INTERP_L4
# name_obs: ['SWOT']
# name_var: SSH
# write_op: True
# path_save: /silenus/PROJECTS/pr-data-ocean/bellemva/obsop/long_serie/config_QGSW/obsop_swot
# compute_op: False
# mask_borders: False
# interp_method: nearest
# gradients: False
# file_corr: None
# name_var_corr: None
# name_coord_corr: {'lon': 'longitude', 'lat': 'latitude', 'time': 'time'}
#
# super: BASIS_BMaux_JAX
# name_mod_var: ssh_bm
# flux: False
# facns: 1.0
# facnlt: 2.0
# npsp: 3.5
# facpsp: 1.5
# file_aux: /home/bellemva/MASSH/mapping/aux/aux_reduced_basis_BM.nc
# lmin: 80
# lmax: 900.0
# factdec: 7.5
# tdecmin: 2.0
# tdecmax: 20.0
# facQ: 1
# file_depth: None
# name_var_depth: {'lon': '', 'lat': '', 'var': ''}
# depth1: 0.0
# depth2: 30.0
# path_background: None
# var_background: None
# norm_time: True
#
# super: BASIS_GAUSS3D_JAX
# name_mod_var: He
# flux: True
# time_dependant: True
# facns: 3.0
# facnlt: 3.0
# sigma_D: 970
# sigma_T: 25
# sigma_Q: 0.015
# fcor: 1
# normalize_fact: False
# time_spinup: None
# flag_variable_Q: False
# path_sad: None
# name_var_sad: {'lon': '', 'lat': '', 'var': ''}
#
# super: BASIS_OFFSET
# name_mod_var: He_offset
# sigma_B: 0.05
#
# super: BASIS_HBC
# name_mod_var: {'HBCX': 'hbcx', 'HBCY': 'hbcy'}
# facns: 3.5
# facnlt: 2.5
# time_dependant: True
# sigma_B_bc: 0.02
# D_bc: 300
# T_bc: 20
# Nwaves: 3
# Ntheta: 2
#
# super: BASIS_GAUSS_ITG
# name_mod_var: itg
# facns: 3.5
# facnlt: 1.0
# D_itg: 300
# sigma_Q: 0.000175
# Nwaves: 3
#
# --> 902 checkpoints to evaluate the cost function
# process observation operators
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [15], in <cell line: 2>()
#       1 from src import inv as inv
# ----> 2 res = inv.Inv(config,State)
#
# File ~/Bellemin-Laponnaz_2026_JAMES/mapping/notebooks/../src/inv.py:47, in Inv(config, State, Model, dict_obs, Obsop, Basis, X, Bc, ssh_truth, *args, **kwargs)
#      44     return Inv_oi(config, State=State, dict_obs=dict_obs)
#      46 elif config.INV.super=='INV_4DVAR':
# ---> 47     return Inv_4Dvar(config, State=State, Model=Model, dict_obs=dict_obs, Obsop=Obsop, Basis=Basis, Bc=Bc)
#      49 else:
#      50     sys.exit(config.INV.super + ' not implemented yet')
#
# File ~/Bellemin-Laponnaz_2026_JAMES/mapping/notebooks/../src/inv.py:344, in Inv_4Dvar(config, State, Model, dict_obs, Obsop, Basis, Bc, verbose, gpu_device)
#     342     var_bc = None
#     343 print('process observation operators')
# --> 344 Obsop.process_obs(var_bc)
#     346 # ### TEST : CORRECTING THE OBSERVATIONS, FOR IMPLEMENTING SEQUENTIAL MAPPING ### --> very preliminary, only functions for multiple OBSOP
#     347 # if config.OBSOP.super is None:
#     348 #     for k,_OBSOP in enumerate(config.OBSOP):
#    (...)
#     368
#     369 # Initial model state
#     370 Model.init(State)
#
# File ~/Bellemin-Laponnaz_2026_JAMES/mapping/notebooks/../src/obsop.py:1814, in Obsop_multi.process_obs(self, var_bc)
#    1811 def process_obs(self, var_bc=None):
#    1813     for _Obsop in self.Obsop:
# -> 1814         _Obsop.process_obs(var_bc)
#
# File ~/Bellemin-Laponnaz_2026_JAMES/mapping/notebooks/../src/obsop.py:858, in Obsop_interp_l3_jax.process_obs(self, var_bc)
#     855 if obs_name not in self.name_obs:
#     856     continue
# --> 858 with xr.open_dataset(obs_file) as ncin:
#     860     lon = ncin[sat_info['name_lon']].values
#     861     lat = ncin[sat_info['name_lat']].values
#
# File ~/.conda/envs/env_massh/lib/python3.10/site-packages/xarray/core/common.py:1471, in DataWithCoords.__exit__(self, exc_type, exc_value, traceback)
#    1470 def __exit__(self, exc_type, exc_value, traceback) -> None:
# -> 1471     self.close()
#
# File ~/.conda/envs/env_massh/lib/python3.10/site-packages/xarray/core/common.py:1254, in DataWithCoords.close(self)
#    1252 """Release any resources linked to this object."""
#    1253 if self._close is not None:
# -> 1254     self._close()
#    1255 self._close = None
#
# File ~/.conda/envs/env_massh/lib/python3.10/site-packages/xarray/backends/netCDF4_.py:597, in NetCDF4DataStore.close(self, **kwargs)
#     596 def close(self, **kwargs):
# --> 597     self._manager.close(**kwargs)
#
# File ~/.conda/envs/env_massh/lib/python3.10/site-packages/xarray/backends/file_manager.py:234, in CachingFileManager.close(self, needs_lock)
#     232 file = self._cache.pop(self._key, default)
#     233 if file is not None:
# --> 234     file.close()
#
# KeyboardInterrupt:
